# %%
# !pip install mysql-connector-python

# %%
import mysql.connector
import datetime

config = {
  'user': 'root',
  'password': 'password',
  'host': '127.0.0.1',
  'database': 'classicmodels',
  'raise_on_warnings': True
}

cnx = mysql.connector.connect(**config)

cursor = cnx.cursor()

query = ("SELECT orderNumber,status, comments, shippedDate FROM orders "
         "WHERE shippedDate BETWEEN %s AND %s")

first_date = datetime.date(2003, 1, 1)
current_date = datetime.date.today()

cursor.execute(query, (first_date, current_date))

for (orderNumber, status, comments, shippedDate) in cursor:
  print("{}, with status {} was shipped on {}\n The coments for this delivery is: {}\n".format(
    orderNumber, status, comments,shippedDate))

cursor.close()
cnx.close()
# Out:
# 10100, with status Shipped was shipped on None
#  The coments for this delivery is: 2003-01-10
#
# 10101, with status Shipped was shipped on Check on availability.
#  The coments for this delivery is: 2003-01-11
#
# 10102, with status Shipped was shipped on None
#  The coments for this delivery is: 2003-01-14
#
# 10103, with status Shipped was shipped on None
#  The coments for this delivery is: 2003-02-02
#
# 10104, with status Shipped was shipped on None
#  The coments for this delivery is: 2003-02-01
#
# 10105, with status Shipped was shipped on None
#  The coments for this delivery is: 2003-02-12
#
# 10106, with status Shipped was shipped on None
#  The coments for this delivery is: 2003-02-21
#
# 10107, with status Shipped was shipped on Difficult to negotiate with customer. We need more marketing materials
#  The coments for this delivery is: 2003-02-26
#
# 10108, with status Shipped was shipped on None
#  The coments for this delivery is: 2003-03-08
#
# ...
